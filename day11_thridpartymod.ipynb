# %%
from PIL import Image

# %%
img=Image.open(r"/content/download (1).jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x275>

# %%
import numpy as np

# %%
ia=np.array(img)
ia
# Out:
# array([[[228, 245, 255],
#         [228, 245, 255],
#         [228, 245, 255],
#         ...,
#         [175, 205, 213],
#         [176, 206, 214],
#         [176, 206, 214]],
#
#        [[228, 245, 255],
#         [228, 245, 255],
#         [228, 245, 255],
#         ...,
#         [174, 204, 212],
#         [175, 205, 213],
#         [175, 205, 213]],
#
#        [[228, 245, 255],
#         [228, 245, 255],
#         [228, 245, 255],
#         ...,
#         [173, 203, 211],
#         [173, 203, 211],
#         [173, 203, 211]],
#
#        ...,
#
#        [[141, 186, 105],
#         [141, 186, 103],
#         [141, 186, 105],
#         ...,
#         [104,   9,   3],
#         [101,   8,   3],
#         [ 99,   8,   3]],
#
#        [[141, 186, 103],
#         [141, 186, 103],
#         [141, 186, 103],
#         ...,
#         [103,   8,   4],
#         [ 99,   8,   3],
#         [ 99,   8,   3]],
#
#        [[141, 186, 103],
#         [141, 186, 103],
#         [141, 186, 103],
# ...

# %%
a=[1,2,6,9,5,4]
type(a)
# Out:
# list

# %%
a=np.array(a)
type(a)
# Out:
# numpy.ndarray

# %%
a.min()
# Out:
# np.int64(1)

# %%
ia.min()
# Out:
# np.uint8(0)

# %%
np.max(ia)
# Out:
# np.uint8(255)

# %%
np.mean(a)
# Out:
# np.float64(4.5)

# %%
np.sqrt(a)
# Out:
# array([1.        , 1.41421356, 2.44948974, 3.        , 2.23606798,
#        2.        ])

# %%
import pandas as pd

# %%
d=pd.read_csv("/content/Pokemon.csv")
d
# Out:
#       number                  name    type1   type2  total   hp  attack  \
# 0          1             Bulbasaur    Grass  Poison    318   45      49
# 1          2               Ivysaur    Grass  Poison    405   60      62
# 2          3              Venusaur    Grass  Poison    525   80      82
# 3          3         Mega Venusaur    Grass  Poison    625   80     100
# 4          3   Gigantamax Venusaur    Grass  Poison    525   80      82
# ...      ...                   ...      ...     ...    ...  ...     ...
# 1067     896             Glastrier      Ice     NaN    580  100     145
# 1068     897             Spectrier    Ghost     NaN    580  100      65
# 1069     898               Calyrex  Psychic   Grass    500  100      80
# 1070     898     Ice Rider Calyrex  Psychic     Ice    680  100     165
# 1071     898  Shadow Rider Calyrex  Psychic   Ghost    680  100      85
#
#       defense  sp_attack  sp_defense  speed  generation  legendary
# ...

# %%
a=10,20,40,50
type(a)
# Out:
# tuple

# %%
d={"name":["Sanjay","sadhana","rithika","ashwin","jana","dharani"],
"course":["mech","ai","ece","cse","aerospace","mba"]}
d
# Out:
# {'name': ['Sanjay', 'sadhana', 'rithika', 'ashwin', 'jana', 'dharani'],
#  'course': ['mech', 'ai', 'ece', 'cse', 'aerospace', 'mba']}

# %%
d=pd.DataFrame(d)
d
# Out:
#       name     course
# 0   Sanjay       mech
# 1  sadhana         ai
# 2  rithika        ece
# 3   ashwin        cse
# 4     jana  aerospace
# 5  dharani        mba

# %%
import matplotlib.pyplot as plt

# %%
sales=[2399,23345,345456,6787]
chocolate=["5star","dairymilk","kitkat","ferroro"]

plt.bar(chocolate,sales)
plt.show()

# %%
li=[]
def fun(x):
  for i in x:
    li.append(i**5)
l=[1,3,5,7,9]
fun(l)
print(li)
# Out:
# [1, 243, 3125, 16807, 59049]

# %%
def fun(x):
  return x**5
l=[1,3,5,7,9]
map(fun,l)
print(li)
# Out:
# [1, 243, 3125, 16807, 59049]

# %%
m=list(map(lambda x:x**5,l))
print(m)
# Out:
# [1, 243, 3125, 16807, 59049]
